# %% [markdown]
# # Streaming Data Acquisition - From Raw Stream to Clean CSV

# %% [markdown]
# ---

# %% [markdown]
# ## Phase 1: Setup and Architecture

# %% [markdown]
# ### Install the necessary libraries:
# 1. **websocket-client**: To establish the persistent connection.
# 2. **pandas**: To process, clean, and export the collected data.

# %%
# !pip install websocket-client pandas
print("Dependencies installed successfully.")
# Out:
# Requirement already satisfied: websocket-client in /home/codespace/.local/lib/python3.12/site-packages (1.8.0)
# Requirement already satisfied: pandas in /home/codespace/.local/lib/python3.12/site-packages (2.3.1)
# Requirement already satisfied: numpy>=1.26.0 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python3 -m pip install --upgrade pip
# Dependencies installed successfully.

# %%
## Import all required Python modules

# %%
import websocket
import json
import time
import threading
import pandas as pd
from datetime import datetime

print("Modules imported.")
# Out:
# Modules imported.

# %% [markdown]
# ### Define Global Configuration and Storage
# This cell sets the target URL and initializes the empty list that will collect all the raw messages pushed from the server.

# %%
# --- Configuration ---
# Target URL for the Binance BTC/USDT trade stream (using the stable fstream endpoint)
STREAM_URL = "wss://fstream.binance.com/ws/btcusdt@trade" 

# --- Global Storage ---
# This list will collect every single message (event) pushed by the server.
raw_data_collector = []

print(f"Target Stream URL set: {STREAM_URL}")
print("Raw data collector initialized.")
# Out:
# Target Stream URL set: wss://fstream.binance.com/ws/btcusdt@trade
# Raw data collector initialized.

# %% [markdown]
# ### Define the `on_open` Callback
# This function runs only once when the persistent connection is successfully established.

# %%
def on_open(ws):
    """Callback: Executed when the connection handshake is successful."""
    print("--- Connection Established. Starting Real-Time Data Stream ---")
    
print("on_open callback defined.")
# Out:
# on_open callback defined.

# %% [markdown]
# ### Define the `on_error` and `on_close` Callbacks
# These functions handle connection failures and the graceful shutdown of the stream.

# %%
def on_error(ws, error):
    """Callback: Executed if an error occurs during the connection."""
    print(f"--- Connection Error: {error} ---")

def on_close(ws, close_status_code, close_msg):
    """Callback: Executed when the connection is intentionally closed."""
    print("--- Connection Closed ---")
    
print("on_error and on_close callbacks defined.")
# Out:
# on_error and on_close callbacks defined.

# %% [markdown]
# ### Define the `on_message` Callback (Raw Capture Logic)
# This is the most critical function. It runs for every incoming message. For the first run, we will not filter anything.

# %%
def on_message(ws, message):
    """Callback: Executed for EVERY message pushed by the server."""
    global raw_data_collector
    
    try:
        data = json.loads(message)
        
        # 1. Store the RAW, unfiltered message dictionary
        raw_data_collector.append(data)
        
        # 2. Extract and format key fields for immediate screen output
        trade_time = datetime.fromtimestamp(data['E'] / 1000).strftime('%H:%M:%S')
        price = float(data.get('p', 0))
        volume = float(data.get('q', 0))
        
        # Print everything that comes in, including potential 0-value keep-alives
        print(f"[{trade_time}] RAW Trade: Price=${price:,.2f} | Volume={volume}")

    except Exception as e:
        # Ignore errors from malformed JSON (rare, but possible)
        pass 
    
print("on_message callback defined for RAW data capture.")
# Out:
# on_message callback defined for RAW data capture.

# %% [markdown]
# ---

# %% [markdown]
# ## Phase 2: RAW Stream Capture and Observation

# %% [markdown]
# ### Create the WebSocket Client Object

# %%
# Clear the collector list before starting a new run
raw_data_collector = []

# Create the WebSocketApp instance, linking the URL to the callback functions
ws = websocket.WebSocketApp(
    STREAM_URL,
    on_message=on_message,
    on_open=on_open,
    on_error=on_error,
    on_close=on_close
)

print("WebSocket client object created, ready to connect.")
# Out:
# WebSocket client object created, ready to connect.

# %% [markdown]
# ### Start, Run, and Close the Stream Listener
# This cell starts the connection in a separate thread and uses time.sleep() to control the duration.

# %%
print("Starting RAW stream listener for 15 seconds. OBSERVE THE OUTPUT CAREFULLY.")

# Run the socket connection in a separate thread
wst = threading.Thread(target=ws.run_forever)
wst.daemon = True
wst.start()

# Hold the main thread execution for 15 seconds
time.sleep(15) 

print("Time's up. Attempting to close connection...")

# Close the connection gracefully.
ws.close() 

print(f"\nFinished RAW capture. Collected {len(raw_data_collector)} total raw messages.")
# Out:
# Starting RAW stream listener for 15 seconds. OBSERVE THE OUTPUT CAREFULLY.
# --- Connection Established. Starting Real-Time Data Stream ---
# [01:41:47] RAW Trade: Price=$114,405.30 | Volume=0.017
# [01:41:47] RAW Trade: Price=$114,405.30 | Volume=0.001
# [01:41:47] RAW Trade: Price=$114,405.30 | Volume=0.019
# [01:41:47] RAW Trade: Price=$114,405.20 | Volume=0.269
# [01:41:47] RAW Trade: Price=$114,405.20 | Volume=0.001
# [01:41:47] RAW Trade: Price=$114,405.30 | Volume=0.001
# [01:41:47] RAW Trade: Price=$114,405.30 | Volume=0.001
# [01:41:48] RAW Trade: Price=$114,405.30 | Volume=0.036
# [01:41:48] RAW Trade: Price=$114,405.20 | Volume=0.028
# [01:41:48] RAW Trade: Price=$114,405.20 | Volume=0.02
# [01:41:48] RAW Trade: Price=$114,405.30 | Volume=0.111
# [01:41:48] RAW Trade: Price=$114,405.30 | Volume=0.107
# [01:41:49] RAW Trade: Price=$114,405.20 | Volume=0.004
# [01:41:49] RAW Trade: Price=$114,405.20 | Volume=0.001
# [01:41:49] RAW Trade: Price=$114,405.30 | Volume=0.031
# [01:41:49] RAW Trade: Price=$114,405.30 | Volume=0.002
# [01:41:49] RAW Trade: Price=$114,405.30 | Volume=0.003
# [01:41:49] RAW Trade: Price=$114,405.30 | Volume=0.021
# [01:41:49] RAW Trade: Price=$114,405.30 | Volume=0.001
# [01:41:49] RAW Trade: Price=$114,405.20 | Volume=0.014
# [01:41:49] RAW Trade: Price=$114,405.20 | Volume=0.002
# [01:41:50] RAW Trade: Price=$114,405.30 | Volume=0.036
# [01:41:50] RAW Trade: Price=$114,405.30 | Volume=0.001
# [01:41:50] RAW Trade: Price=$114,405.20 | Volume=0.064
# [01:41:50] RAW Trade: Price=$114,405.20 | Volume=0.001
# [01:41:50] RAW Trade: Price=$114,405.20 | Volume=0.035
# [01:41:50] RAW Trade: Price=$114,405.20 | Volume=0.001
# [01:41:50] RAW Trade: Price=$114,405.20 | Volume=0.005
# [01:41:50] RAW Trade: Price=$114,405.30 | Volume=0.022
# [01:41:50] RAW Trade: Price=$114,405.30 | Volume=0.01
# [01:41:50] RAW Trade: Price=$114,405.20 | Volume=0.185
# [01:41:50] RAW Trade: Price=$114,405.30 | Volume=0.01
# [01:41:51] RAW Trade: Price=$114,405.30 | Volume=0.002
# [01:41:51] RAW Trade: Price=$114,405.30 | Volume=0.003
| Volume=0.001
# [01:41:58] RAW Trade: Price=$114,385.60 | Volume=0.002
# [01:41:58] RAW Trade: Price=$114,385.60 | Volume=0.001
# [01:41:58] RAW Trade: Price=$114,385.60 | Volume=0.001
# [01:41:58] RAW Trade: Price=$114,385.60 | Volume=0.001
# [01:41:58] RAW Trade: Price=$114,385.60 | Volume=0.001
# [01:41:58] RAW Trade: Price=$114,385.60 | Volume=0.001
# [01:41:58] RAW Trade: Price=$114,385.60 | Volume=0.001
# [01:41:58] RAW Trade: Price=$114,385.60 | Volume=0.024
# [01:41:58] RAW Trade: Price=$114,385.70 | Volume=0.037
# [01:41:58] RAW Trade: Price=$114,385.60 | Volume=0.008
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.243
# [01:41:59] RAW Trade: Price=$114,385.70 | Volume=0.001
# [01:41:59] RAW Trade: Price=$114,385.70 | Volume=0.043
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.001
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.004
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.035
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.014
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.158
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.095
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.001
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.012
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.004
# [01:41:59] RAW Trade: Price=$114,385.70 | Volume=0.002
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.004
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.003
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.096
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.022
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.094
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.001
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.012
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.001
# [01:41:59] RAW Trade: Price=$0.00 | Volume=0.0
# [01:41:59] RAW Trade: Price=$114,385.70 | Volume=0.001
# [01:41:59] RAW Trade: Price=$114,385.70 | Volume=0.001
# [01:41:59] RAW Trade: Price=$114,385.70 | Volume=0.035
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.34
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.177
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.045
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.148
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.207
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.163
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.165
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.125
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.001
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.356
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.033
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.33
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.5
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.001
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.047
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.057
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.159
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.295
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.643
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.001
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.623
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.8
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.001
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.43
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.52
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.469
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.531
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.77
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.08
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.004
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.007
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.03
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.002
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.019
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.148
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.153
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.179
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.026
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.026
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.026
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.026
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.026
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.026
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.045
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.16
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.04
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.002
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.001
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.009
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.001
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.001
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.49
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.969
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.027
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.04
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.2
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.029
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.029
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.029
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.03
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.03
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.029
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.029
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.03
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.029
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.029
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.029
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.029
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.03
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.029
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.029
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.029
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.029
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.029
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.029
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.03
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.001
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.001
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.002
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.08
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.002
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.05
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.002
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.001
# [01:41:59] RAW Trade: Price=$114,385.60 | Volume=0.002
# [01:41:59] RAW Trade: Price=$114,385.50 | Volume=0.001
# [01:41:59] RAW Trade: Price=$114,385.50 | Volume=0.001
# [01:41:59] RAW Trade: Price=$114,385.50 | Volume=0.001
# [01:41:59] RAW Trade: Price=$114,385.50 | Volume=0.001
# [01:41:59] RAW Trade: Price=$114,385.50 | Volume=0.001
# [01:41:59] RAW Trade: Price=$114,385.30 | Volume=0.001
# [01:41:59] RAW Trade: Price=$114,385.20 | Volume=0.001
# [01:41:59] RAW Trade: Price=$114,385.20 | Volume=0.05
# [01:41:59] RAW Trade: Price=$114,385.20 | Volume=0.005
# [01:41:59] RAW Trade: Price=$114,385.20 | Volume=0.026
# [01:41:59] RAW Trade: Price=$114,385.20 | Volume=0.03
# [01:41:59] RAW Trade: Price=$114,385.20 | Volume=0.012
# [01:41:59] RAW Trade: Price=$114,385.20 | Volume=0.013
# [01:41:59] RAW Trade: Price=$114,385.20 | Volume=0.001
# [01:41:59] RAW Trade: Price=$114,385.20 | Volume=0.01
# [01:41:59] RAW Trade: Price=$114,385.20 | Volume=0.018
# [01:41:59] RAW Trade: Price=$114,385.20 | Volume=0.011
# [01:41:59] RAW Trade: Price=$114,385.20 | Volume=0.012
# [01:41:59] RAW Trade: Price=$114,385.20 | Volume=0.005
# [01:41:59] RAW Trade: Price=$114,385.20 | Volume=0.001
# [01:41:59] RAW Trade: Price=$114,385.20 | Volume=0.009
# [01:41:59] RAW Trade: Price=$114,385.20 | Volume=0.03
# [01:41:59] RAW Trade: Price=$114,385.20 | Volume=0.086
# [01:41:59] RAW Trade: Price=$114,385.20 | Volume=0.017
# [01:41:59] RAW Trade: Price=$114,385.20 | Volume=0.001
# [01:41:59] RAW Trade: Price=$114,385.20 | Volume=0.017
# [01:41:59] RAW Trade: Price=$114,385.20 | Volume=0.029
# [01:41:59] RAW Trade: Price=$114,385.20 | Volume=0.025
# [01:41:59] RAW Trade: Price=$114,385.20 | Volume=0.011
# [01:41:59] RAW Trade: Price=$114,385.20 | Volume=0.018
# [01:41:59] RAW Trade: Price=$114,385.20 | Volume=0.026
# [01:41:59] RAW Trade: Price=$114,385.20 | Volume=0.014
# [01:42:00] RAW Trade: Price=$114,385.20 | Volume=0.012
# [01:42:00] RAW Trade: Price=$114,385.20 | Volume=0.037
# [01:42:00] RAW Trade: Price=$114,385.20 | Volume=0.053
# [01:42:00] RAW Trade: Price=$114,385.20 | Volume=0.014
# [01:42:00] RAW Trade: Price=$114,385.20 | Volume=0.003
# [01:42:00] RAW Trade: Price=$114,385.20 | Volume=0.002
# [01:42:00] RAW Trade: Price=$114,385.20 | Volume=0.031
# [01:42:00] RAW Trade: Price=$114,385.20 | Volume=0.01
# [01:42:00] RAW Trade: Price=$114,385.20 | Volume=0.026
# [01:42:00] RAW Trade: Price=$114,385.20 | Volume=0.028
# [01:42:00] RAW Trade: Price=$114,385.20 | Volume=0.028
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.009
# [01:42:00] RAW Trade: Price=$114,385.20 | Volume=0.001
# [01:42:00] RAW Trade: Price=$114,385.20 | Volume=0.024
# [01:42:00] RAW Trade: Price=$0.00 | Volume=0.0
# [01:42:00] RAW Trade: Price=$114,385.20 | Volume=0.014
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.001
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.008
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.001
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=1.642
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.423
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.001
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.007
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.03
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.37
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.182
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.2
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.001
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.001
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.001
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.005
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.001
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.005
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.001
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.254
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.582
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.36
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.491
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=1.059
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.313
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.043
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=2.025
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.194
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.062
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.032
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.039
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.04
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.055
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.052
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=1.265
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.364
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.093
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.294
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.048
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.077
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.158
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.055
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.121
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=1.057
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.001
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.001
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.017
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.086
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.001
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.013
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.055
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.349
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.087
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.001
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.002
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.268
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.052
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.006
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.272
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.002
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.25
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.004
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.004
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.003
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.24
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.097
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.001
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.003
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.199
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.281
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.006
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.007
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.006
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.006
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.006
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.004
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.151
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.009
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.006
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.001
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.004
# [01:42:00] RAW Trade: Price=$114,385.30 | Volume=0.02
# [01:42:00] RAW Trade: Price=$114,385.40 | Volume=0.001
# [01:42:00] RAW Trade: Price=$114,385.40 | Volume=0.001
# [01:42:00] RAW Trade: Price=$114,385.40 | Volume=0.002
# [01:42:00] RAW Trade: Price=$114,385.40 | Volume=0.002
# [01:42:00] RAW Trade: Price=$114,385.40 | Volume=0.002
# [01:42:00] RAW Trade: Price=$114,385.50 | Volume=0.002
# [01:42:00] RAW Trade: Price=$114,385.50 | Volume=0.002
# [01:42:00] RAW Trade: Price=$114,385.60 | Volume=0.001
# [01:42:00] RAW Trade: Price=$114,385.70 | Volume=0.003
# [01:42:00] RAW Trade: Price=$114,385.70 | Volume=0.002
# [01:42:00] RAW Trade: Price=$114,385.70 | Volume=0.003
# [01:42:00] RAW Trade: Price=$114,385.70 | Volume=0.001
# [01:42:00] RAW Trade: Price=$114,385.70 | Volume=0.1
# [01:42:00] RAW Trade: Price=$114,385.70 | Volume=0.009
# [01:42:00] RAW Trade: Price=$114,385.70 | Volume=0.01
# [01:42:00] RAW Trade: Price=$114,385.70 | Volume=0.012
# [01:42:00] RAW Trade: Price=$114,385.70 | Volume=0.012
# [01:42:00] RAW Trade: Price=$114,385.70 | Volume=0.009
# [01:42:00] RAW Trade: Price=$114,385.70 | Volume=0.021
# [01:42:00] RAW Trade: Price=$114,385.70 | Volume=0.012
# [01:42:00] RAW Trade: Price=$114,385.70 | Volume=0.009
# [01:42:00] RAW Trade: Price=$114,385.70 | Volume=0.023
# [01:42:00] RAW Trade: Price=$114,385.70 | Volume=0.028
# [01:42:00] RAW Trade: Price=$114,385.70 | Volume=0.009
# [01:42:00] RAW Trade: Price=$114,385.70 | Volume=0.007
# [01:42:00] RAW Trade: Price=$114,385.70 | Volume=0.008
# [01:42:00] RAW Trade: Price=$114,385.70 | Volume=0.019
# [01:42:00] RAW Trade: Price=$114,385.70 | Volume=0.052
# [01:42:00] RAW Trade: Price=$114,385.70 | Volume=0.009
# [01:42:00] RAW Trade: Price=$114,385.70 | Volume=0.008
# [01:42:00] RAW Trade: Price=$114,385.70 | Volume=0.002
# [01:42:00] RAW Trade: Price=$114,385.70 | Volume=0.002
# [01:42:00] RAW Trade: Price=$114,385.70 | Volume=0.002
# [01:42:00] RAW Trade: Price=$114,385.70 | Volume=0.001
# [01:42:00] RAW Trade: Price=$114,385.70 | Volume=0.04
# [01:42:00] RAW Trade: Price=$114,385.70 | Volume=0.087
# [01:42:00] RAW Trade: Price=$114,385.70 | Volume=0.001
# [01:42:00] RAW Trade: Price=$114,385.70 | Volume=0.018
# [01:42:00] RAW Trade: Price=$114,385.70 | Volume=0.011
# [01:42:00] RAW Trade: Price=$114,385.70 | Volume=0.007
# [01:42:00] RAW Trade: Price=$114,385.70 | Volume=0.006
# [01:42:00] RAW Trade: Price=$114,385.70 | Volume=0.001
# [01:42:00] RAW Trade: Price=$114,385.70 | Volume=0.001
# [01:42:00] RAW Trade: Price=$114,385.80 | Volume=0.001
# [01:42:00] RAW Trade: Price=$114,385.80 | Volume=0.002
# [01:42:00] RAW Trade: Price=$114,385.80 | Volume=0.001
# [01:42:00] RAW Trade: Price=$114,385.80 | Volume=0.002
# [01:42:00] RAW Trade: Price=$114,386.30 | Volume=0.002
# [01:42:00] RAW Trade: Price=$114,386.70 | Volume=0.002
# [01:42:00] RAW Trade: Price=$114,386.70 | Volume=0.002
# [01:42:00] RAW Trade: Price=$114,386.90 | Volume=0.002
# [01:42:00] RAW Trade: Price=$114,387.50 | Volume=0.002
# [01:42:00] RAW Trade: Price=$114,387.80 | Volume=0.002
# [01:42:00] RAW Trade: Price=$114,388.00 | Volume=0.001
# [01:42:00] RAW Trade: Price=$114,388.10 | Volume=0.002
# [01:42:00] RAW Trade: Price=$114,388.20 | Volume=0.001
# [01:42:00] RAW Trade: Price=$114,388.30 | Volume=0.002
# [01:42:00] RAW Trade: Price=$114,388.50 | Volume=0.002
# [01:42:00] RAW Trade: Price=$114,388.70 | Volume=0.002
# [01:42:00] RAW Trade: Price=$114,389.00 | Volume=0.002
# [01:42:00] RAW Trade: Price=$114,389.00 | Volume=0.002
# [01:42:00] RAW Trade: Price=$114,389.00 | Volume=0.001
# [01:42:00] RAW Trade: Price=$114,389.00 | Volume=0.001
# [01:42:00] RAW Trade: Price=$114,389.00 | Volume=0.001
# [01:42:00] RAW Trade: Price=$114,389.00 | Volume=0.001
# [01:42:00] RAW Trade: Price=$114,389.30 | Volume=0.002
# [01:42:00] RAW Trade: Price=$114,389.60 | Volume=0.002
# [01:42:00] RAW Trade: Price=$114,389.90 | Volume=0.002
# [01:42:00] RAW Trade: Price=$114,390.00 | Volume=0.002
# [01:42:00] RAW Trade: Price=$114,390.00 | Volume=0.001
# [01:42:00] RAW Trade: Price=$114,390.00 | Volume=0.001
# [01:42:00] RAW Trade: Price=$114,390.10 | Volume=0.002
# [01:42:00] RAW Trade: Price=$114,390.50 | Volume=0.001
# [01:42:00] RAW Trade: Price=$114,390.50 | Volume=0.002
# [01:42:00] RAW Trade: Price=$114,390.50 | Volume=0.003
# [01:42:00] RAW Trade: Price=$114,390.50 | Volume=0.034
# [01:42:00] RAW Trade: Price=$114,390.50 | Volume=0.027
# [01:42:00] RAW Trade: Price=$114,390.40 | Volume=0.001
# [01:42:00] RAW Trade: Price=$114,390.40 | Volume=0.04
# Time's up. Attempting to close connection...
# --- Connection Closed ---
#
# Finished RAW capture. Collected 702 total raw messages.

# %% [markdown]
# ### Commentary - Why the $0 Trades?
#
# --- Observation: The Data Quality Problem ---
#
# You should have observed several messages showing Price=$0.00 or Volume=0.
#
# These are **Keep-Alive (Ping/Pong) Messages**. They are network heartbeats, NOT valid trades.
#
# If we analyzed this raw data, the 0-values would skew our average price and volume calculations.
#
# Our next step is to apply a **Filter** to discard them.

# %% [markdown]
# ---

# %% [markdown]
# ## Phase 3: Data Transformation and Export

# %% [markdown]
# ### Load Raw Data into Pandas
# This is the start of the Transformation (T) phase from ETL.

# %%
# Convert the list of dictionaries collected in Phase 2 into a Pandas DataFrame
df_raw = pd.DataFrame(raw_data_collector)

print(f"DataFrame loaded with {len(df_raw)} raw messages.")
print("Raw DataFrame columns:")
print(df_raw.columns.tolist())
display(df_raw.head())
# Out:
# DataFrame loaded with 702 raw messages.
# Raw DataFrame columns:
# ['e', 'E', 'T', 's', 't', 'p', 'q', 'X', 'm']
#        e              E              T        s           t          p      q  \
# 0  trade  1759196507396  1759196507396  BTCUSDT  6667024359  114405.30  0.017
# 1  trade  1759196507396  1759196507396  BTCUSDT  6667024360  114405.30  0.001
# 2  trade  1759196507396  1759196507396  BTCUSDT  6667024361  114405.30  0.019
# 3  trade  1759196507416  1759196507416  BTCUSDT  6667024362  114405.20  0.269
# 4  trade  1759196507516  1759196507516  BTCUSDT  6667024363  114405.20  0.001
#
#         X      m
# 0  MARKET  False
# 1  MARKET  False
# 2  MARKET  False
# 3  MARKET   True
# 4  MARKET   True

# %% [markdown]
# ### Data Preparation (Type Conversion)
# The price and volume columns were read as strings or objects. We must convert them to numeric types before filtering.

# %%
# Convert price ('p') and volume ('q') columns to numeric types.
df_raw['p'] = pd.to_numeric(df_raw['p'], errors='coerce')
df_raw['q'] = pd.to_numeric(df_raw['q'], errors='coerce')

print("Price ('p') and Volume ('q') columns converted to numeric (float).")
# Out:
# Price ('p') and Volume ('q') columns converted to numeric (float).

# %% [markdown]
# ### Apply the Cleaning Filter
# This cell applies the filter to eliminate the keep-alive messages.

# %%
print(f"Messages before filtering: {len(df_raw)}")

# --- APPLY THE DATA QUALITY FILTER ---
# A valid trade must have a positive price AND a positive volume.
df_clean = df_raw[(df_raw['p'] > 0) & (df_raw['q'] > 0)].copy()

print(f"Messages after filtering: {len(df_clean)}")
print(f"Successfully filtered out {len(df_raw) - len(df_clean)} keep-alive messages.")

display(df_clean.head())
# Out:
# Messages before filtering: 702
# Messages after filtering: 700
# Successfully filtered out 2 keep-alive messages.
#        e              E              T        s           t         p      q  \
# 0  trade  1759196507396  1759196507396  BTCUSDT  6667024359  114405.3  0.017
# 1  trade  1759196507396  1759196507396  BTCUSDT  6667024360  114405.3  0.001
# 2  trade  1759196507396  1759196507396  BTCUSDT  6667024361  114405.3  0.019
# 3  trade  1759196507416  1759196507416  BTCUSDT  6667024362  114405.2  0.269
# 4  trade  1759196507516  1759196507516  BTCUSDT  6667024363  114405.2  0.001
#
#         X      m
# 0  MARKET  False
# 1  MARKET  False
# 2  MARKET  False
# 3  MARKET   True
# 4  MARKET   True

# %% [markdown]
# ### Add Human-Readable Columns
# The raw data uses short keys like 'E' (Event Time) and 's' (Symbol). We create descriptive columns for the final CSV.

# %%
# Convert 'E' (milliseconds since epoch) to a readable timestamp
df_clean['Trade_Time'] = pd.to_datetime(df_clean['E'], unit='ms')

# Create descriptive columns
df_clean['Price_USD'] = df_clean['p']
df_clean['Volume_BTC'] = df_clean['q']

print("Human-readable columns (Trade_Time, Price_USD, Volume_BTC) created.")
# Out:
# Human-readable columns (Trade_Time, Price_USD, Volume_BTC) created.

# %% [markdown]
# ### Select Final Columns
# Select only the essential, clean, and formatted columns for the final file.

# %%
# Select and rename final columns for a clean output structure
df_final = df_clean[['Trade_Time', 'Price_USD', 'Volume_BTC', 's']].rename(
    columns={'s': 'Symbol'}
)

print("Final DataFrame structure prepared.")
display(df_final.head())
# Out:
# Final DataFrame structure prepared.
#                Trade_Time  Price_USD  Volume_BTC   Symbol
# 0 2025-09-30 01:41:47.396   114405.3       0.017  BTCUSDT
# 1 2025-09-30 01:41:47.396   114405.3       0.001  BTCUSDT
# 2 2025-09-30 01:41:47.396   114405.3       0.019  BTCUSDT
# 3 2025-09-30 01:41:47.416   114405.2       0.269  BTCUSDT
# 4 2025-09-30 01:41:47.516   114405.2       0.001  BTCUSDT

# %% [markdown]
# ### Export to CSV
# This is the Load (L) phase of ETL.

# %%
# Define the output filename
output_filename = 'btc_usdt_stream_clean.csv'

# Export the clean DataFrame to a CSV file without the pandas index
df_final.to_csv(output_filename, index=False)

print(f"--- Load Phase Complete ---")
print(f"Clean, filtered stream data successfully exported to: {output_filename}")
# Out:
# --- Load Phase Complete ---
# Clean, filtered stream data successfully exported to: btc_usdt_stream_clean.csv
